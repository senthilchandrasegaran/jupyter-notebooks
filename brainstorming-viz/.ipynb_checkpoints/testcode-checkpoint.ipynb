# %%
import nltk
import os
import re
import itertools
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import codecs
from textblob import TextBlob
import pandas as pd
import re
# %matplotlib inline
# %load_ext autoreload

def removeObservations(test_str):
    # removes all text within parantheses
    # these are usually observations by the transcriber
    # and thus should not be considered in content analysis
    # code from http://stackoverflow.com/questions/14596884/remove-text-between-and-in-python
    ret = ''
    skip1c = 0
    skip2c = 0
    for i in test_str:
        if i == '[':
            skip1c += 1
        elif i == '(':
            skip2c += 1
        elif i == ']' and skip1c > 0:
            skip1c -= 1
        elif i == ')'and skip2c > 0:
            skip2c -= 1
        elif skip1c == 0 and skip2c == 0:
            ret += i
    return ret
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\utils\fixes.py:64: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if 'order' in inspect.getargspec(np.copy)[0]:

# %%
# Open and read transcripts in NLTK
f1=codecs.open('../../../private/brainstorming_viz_data/free_group/teamA_part1_divergent.txt', 'r', encoding='utf-8')
f2=codecs.open('../../../private/brainstorming_viz_data/free_group/teamA_part2_convergent.txt', 'r', encoding='utf-8')
f1Temp = codecs.open('tempASCII', 'w', encoding='ascii', errors='ignore')
f2Temp = codecs.open('tempASCII', 'w', encoding='ascii', errors='ignore')
f1Temp.write('free_group/teamA_part1_divergent_bak.txt')
f2Temp.write('free_group/teamA_part1_convergent_bak.txt')
divergent_raw = f1.read()
convergent_raw = f2.read()
regex = re.compile(".*?\[(.*?)\]")
divergent = removeObservations(divergent_raw)
convergent = removeObservations(convergent_raw)

# %%
# Extract Noun phrases using TextBlob
blobDivergent = TextBlob(divergent)
blobConvergent = TextBlob(convergent)
nounDiv = blobDivergent.np_counts
nounConv = blobConvergent.np_counts
dfnp1 = pd.DataFrame(columns=['Noun phrases in Divergent phase', 'Frequencies'])
dfnp2 = pd.DataFrame(columns=['Noun phrases in Convergent phase', 'Frequencies'])
u=1
for i in nounDiv:
    dfnp1.loc[u] = [i, nounDiv[i]]
    u+=1

u=1
for i in nounConv:
    dfnp2.loc[u] = [i, nounConv[i]]
    u+=1
    
print("The total number of noun phrases in the divergent phase:", len(nounDiv))
dfnp1.head(15)
# Out:
# The total number of noun phrases in the divergent phase: 214
#    Noun phrases in Divergent phase  Frequencies
# 1                  jack-in-the-box            3
# 2                    freshman year            2
# 3                    army man idea            1
# 4                     blank sheets            1
# 5                       marble run            2
# 6                       time clock            1
# 7                   it’s halloween            1
# 8                     like—the way            1
# 9                             well            2
# 10                     it’ll trace            1
# 11                             say            1
# 12               different clothes            1
# 13                      ape swings            1
# 14                         they’re            3
# 15                       ball sort            1

# %%
print("The total number of noun phrases in the convergent phase:", len(nounConv))
dfnp2.head(15)
# Out:
# The total number of noun phrases in the convergent phase: 103
#    Noun phrases in Convergent phase  Frequencies
# 1                    drawing sheets            1
# 2                      don’t wan na            1
# 3                   be—like suppose            1
# 4                               say            1
# 5                              moms            1
# 6                     dragon turtle            1
# 7                 mechanical motion            1
# 8                     people’s oars            1
# 9                      paper only.”            1
# 10                     one’s gon na            1
# 11                            let’s            1
# 12                             we’d            1
# 13                           mine’s            1
# 14                           thanks            1
# 15                           single            1

# %%
# Common noun phrases in both phases
common = {}
notcommon = {}
dfc = pd.DataFrame(columns=["Common noun phrases", "Divergent", "Convergent"])
u=1
for i in nounDiv:
    if i in nounConv:
        common[i] = min(nounDiv[i], nounConv[i])
        notcommon[i] = (nounDiv[i], nounConv[i])
        dfc.loc[u] = [i, nounDiv[i], nounConv[i]]
        u+=1
dfc
# Out:
#    Common noun phrases  Divergent  Convergent
# 1                  say          1           1
# 2                let’s          3           1
# 3                 have          2           2
# 4                 cool          1           1
# 5         one’s gon na          1           1
# 6            good idea          3           1
# 7               here’s          1           1
# 8          whole thing          1           1
# 9                right          1           1
# 10   mechanical motion          1           1
# 11                  rc          3           1
# 12                okay         10           2
# 13              gon na          5           4
# 14              that’s         10           1
# 15                yeah         55          14
# 16                 i’m          3           5
# 17              shoots          2           2
# 18                i’ll          1           2
# 19                it’s          8           2
# 20              wan na          3           2

# %%
# Noun phrases that can be removed:
to_be_removed = [u'okay', u'yeah']
keys_to_delete = []
for key in common.keys():
    if key in to_be_removed:
        keys_to_delete.append(key)
for key in keys_to_delete:
    del common[key] # could not have deleted item from iterable 
                    # from within the loop
ccommon=common.keys()

# %%
# count co-occurrences of common noun phrases in sentences
def occurrences(source, terms):
    ALL_sentences=sent_tokenize(source) # creates a list of sentences
    combinations_terms = list(itertools.combinations(terms,2)) # NC2 of terms
    n = len(combinations_terms)
    occurlist = []
    for i in range(1, n):
        for j in ALL_sentences:
            temp = list(combinations_terms[i])
            # Find every combination of term 1 followed by term 2 in
            # term pair (1,2)
            out=re.compile(str(temp[0]) + '(.*?)' + str(temp[1]), 
                           re.DOTALL | re.IGNORECASE).findall(j)
            if out:
                print(out)
                occurlist.append(str(temp[0]) + ' - ' + str(temp[1]))
            # Find every combination of term 2 followed by term 1 in
            # term pair (1,2)
            out2 = re.compile(str(temp[1]) + '(.*?)' + str(temp[0]),
                             re.DOTALL | re.IGNORECASE).findall(j)
            if out2:
                occurlist.append(str(temp[1]) + ' - ' + str(temp[0]))
    occurdict = {}
    # count occurrences of term pairs
    for i in occurlist:
        if i not in occurdict:
            occurdict[i] = 1
        else : 
            occurdict[i] = occurdict[i] + 1
    return occurdict

Divdict = occurrences(divergent, ccommon)
# Convdict = occurrences(convergent, ccommon)
# Out:
# ['We’re all gonna draw one thing at the same time, or are we each drawing our own individual idea?', 'I think he’s wanting us to draw one thing at a time and then go on to another concept and just update it.', 'Each person draws separately and explains what others sticks on the wall.', 'It would probably have helped if we could actually see .', 'I can read like the first word on this side, and that’s about it.', 'Oh, yeah?', 'There’s an idea.', 'RC car, but it has that Arduino checker on it, that proxy thing.', 'It tracks the closest thing to it, the closest object to it.', 'Swivel head and an RC car to follow objects.', 'That’s a good idea.', 'Yeah.', 'Do we use these sketches?', 'Are we what?', 'Do we use these?', 'I don’t know.', 'I think he was just using this one.', 'This is your pencil.', 'How is this gonna help, though?', 'What I was thinking is you know that we were talking about that ping checker, that Arduino that senses the location?', 'Right, right.', 'You put this on top of your RC car and your car will go to the closest object.', 'Closest or the farthest object?', 'Probably the close—welcome—\r\nBecause if it goes to the closest object, it’s gonna bang into it, right?', 'Yeah.', 'So that’s the point?', 'Yeah.', 'Okay.', 'It wasn’t my idea.', 'Wanna see if—any better?', 'What do you guys think?', 'I was thinking if it’s the farthest away, so it could probably avoid all the obstacles and make it way through.', 'Okay.', 'That’s just an idea.', 'That’s good.', 'Explain it, and once it’s done, put it on the wall.', 'Okay.', 'Then we can like—the way this looks is it has two giant cylinders on it.', 'We could make it look like a face or something, put eyebrows on it.', 'Then it’ll have to turn to sense things.', 'Does it turn on its own, or do you turn it?', 'You have to put a servo on it, I think.', 'Oh, so then it turns continuously like a fan.', 'Yeah.', 'Moving continuously or it will track back and forward or something.', 'If you need more pushpins, let us know.', 'Any ideas?', 'What do you wanna try?', 'What else we got?', 'If you want more blank sheets, also just let us know.', 'To go along with what we were doing in lecture Tuesday.', 'toys?', 'Do you wanna go with the chess idea for giant man?', 'I got another idea.', 'What if you have like a chessboard, but not like a cloth one, electronic one?', 'You can control those men by having like tablets in your hand or your phone.', 'You play it on your phone and then it moves a similar thing on the board.', 'It’s like if you ask the soldier to move a step ahead, so that’s how it’s going to move there.', 'You wouldn’t do it manually; you’d rather do it on your phone and then it does happen on there.', 'You can add a lot of features.', 'You can have someone probably like shooting sound or something so that you can hear the other person—\r\nOkay.', 'That would require a lot of software and stuff.', 'Yeah.', 'I mean we can do the moving mechanism on the chessboard.', 'That would be a lot of stuff for this class.', 'I know we talked about a giant army man game.', 'This is .', 'You’re pointing.', 'How can we make this mechanical?', 'Make what mechanical?', 'Yeah.', 'We have to make it nontrivial motion.', 'I was thinking we could do a—have you ever seen those soccer or hockey games where they have the players on little swivels?', 'Oh, yeah, yeah.', 'They can slide back and forth as well.', 'I was thinking maybe we could do something like that with the army one.', 'Okay.', 'You mean like a foosball machine?', 'Yeah, sort of.', 'Little army men.', 'I think we want to build on that, but there’s no motion in that yet.', 'Did you see all those online flash games where you—like if there’s a plane coming in and you specify a path and then you’re supposed to direct it towards the runway?', 'Then there’s like planes coming from all sides and you’re just supposed to make sure that it goes—\r\n?', 'Yeah, so going back to your idea, the Arduino, we could probably have a plane and the ...
# combinations-terms =  [('it’s', 'cool'), ('it’s', 'rc'), ('it’s', 'gon na'), ('it’s', 'one’s gon na'), ('it’s', 'wan na'), ('it’s', 'here’s'), ('it’s', 'have'), ('it’s', 'good idea'), ('it’s', 'say'), ('it’s', 'whole thing'), ('it’s', 'i’m'), ('it’s', 'mechanical motion'), ('it’s', 'that’s'), ('it’s', 'i’ll'), ('it’s', 'shoots'), ('it’s', 'right'), ('it’s', 'let’s'), ('cool', 'rc'), ('cool', 'gon na'), ('cool', 'one’s gon na'), ('cool', 'wan na'), ('cool', 'here’s'), ('cool', 'have'), ('cool', 'good idea'), ('cool', 'say'), ('cool', 'whole thing'), ('cool', 'i’m'), ('cool', 'mechanical motion'), ('cool', 'that’s'), ('cool', 'i’ll'), ('cool', 'shoots'), ('cool', 'right'), ('cool', 'let’s'), ('rc', 'gon na'), ('rc', 'one’s gon na'), ('rc', 'wan na'), ('rc', 'here’s'), ('rc', 'have'), ('rc', 'good idea'), ('rc', 'say'), ('rc', 'whole thing'), ('rc', 'i’m'), ('rc', 'mechanical motion'), ('rc', 'that’s'), ('rc', 'i’ll'), ('rc', 'shoots'), ('rc', 'right'), ('rc', 'let’s'), ('gon na', 'one’s gon na'), ('gon na', 'wan na'), ('gon na', 'here’s'), ('gon na', 'have'), ('gon na', 'good idea'), ('gon na', 'say'), ('gon na', 'whole thing'), ('gon na', 'i’m'), ('gon na', 'mechanical motion'), ('gon na', 'that’s'), ('gon na', 'i’ll'), ('gon na', 'shoots'), ('gon na', 'right'), ('gon na', 'let’s'), ('one’s gon na', 'wan na'), ('one’s gon na', 'here’s'), ('one’s gon na', 'have'), ('one’s gon na', 'good idea'), ('one’s gon na', 'say'), ('one’s gon na', 'whole thing'), ('one’s gon na', 'i’m'), ('one’s gon na', 'mechanical motion'), ('one’s gon na', 'that’s'), ('one’s gon na', 'i’ll'), ('one’s gon na', 'shoots'), ('one’s gon na', 'right'), ('one’s gon na', 'let’s'), ('wan na', 'here’s'), ('wan na', 'have'), ('wan na', 'good idea'), ('wan na', 'say'), ('wan na', 'whole thing'), ('wan na', 'i’m'), ('wan na', 'mechanical motion'), ('wan na', 'that’s'), ('wan na', 'i’ll'), ('wan na', 'shoots'), ('wan na', 'right'), ('wan na', 'let’s'), ('here’s', 'have'), ('here’s', 'good idea'), ('here’s', 'say'), ('here’s', 'whole thing'), ('here’s', 'i’m'), ('here’s', 'mechanical motion'), ('here’s', 'that’s'), ('here’s', 'i’ll'), ('here’s', 'shoots'), ('here’s', 'right'), ('here’s', 'let’s'), ('have', 'good idea'), ('have', 'say'), ('have', 'whole thing'), ('have', 'i’m'), ('have', 'mechanical motion'), ('have', 'that’s'), ('have', 'i’ll'), ('have', 'shoots'), ('have', 'right'), ('have', 'let’s'), ('good idea', 'say'), ('good idea', 'whole thing'), ('good idea', 'i’m'), ('good idea', 'mechanical motion'), ('good idea', 'that’s'), ('good idea', 'i’ll'), ('good idea', 'shoots'), ('good idea', 'right'), ('good idea', 'let’s'), ('say', 'whole thing'), ('say', 'i’m'), ('say', 'mechanical motion'), ('say', 'that’s'), ('say', 'i’ll'), ('say', 'shoots'), ('say', 'right'), ('say', 'let’s'), ('whole thing', 'i’m'), ('whole thing', 'mechanical motion'), ('whole thing', 'that’s'), ('whole thing', 'i’ll'), ('whole thing', 'shoots'), ('whole thing', 'right'), ('whole thing', 'let’s'), ('i’m', 'mechanical motion'), ('i’m', 'that’s'), ('i’m', 'i’ll'), ('i’m', 'shoots'), ('i’m', 'right'), ('i’m', 'let’s'), ('mechanical motion', 'that’s'), ('mechanical motion', 'i’ll'), ('mechanical motion', 'shoots'), ('mechanical motion', 'right'), ('mechanical motion', 'let’s'), ('that’s', 'i’ll'), ('that’s', 'shoots'), ('that’s', 'right'), ('that’s', 'let’s'), ('i’ll', 'shoots'), ('i’ll', 'right'), ('i’ll', 'let’s'), ('shoots', 'right'), ('shoots', 'let’s'), ('right', 'let’s')]
# [' like if you ask the soldier to move a step ahead, so ']
# [' gonna bang into it, ']
# ['ist doll, ']
# [' a walking crab ']
# [' like a strong weak magnet between this piece of metal and this ball ']
# [' a pen or a marker ']
# [' a target on the wall and you can just try to get—you line up the gorilla or the penguins and it ']
# [' to draw something, choose something, ']
# [' ']
# [' this ball ']
