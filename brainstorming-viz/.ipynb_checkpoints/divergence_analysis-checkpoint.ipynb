# %%
# Code thanks to Moses Boudourides, Sergios Lenis & Pantelis Vikatos
# Their version (largely unchanged except for fixing some python 3.5 incompatibilities)
# can be seen here: http://mboudour.github.io/2016/03/22/Clinton-Sanders-Word-Nets.html
import nltk
import os
import re
import itertools
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import codecs
from textblob import TextBlob
import pandas as pd
import re
# %matplotlib inline
# %load_ext autoreload
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\utils\fixes.py:64: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if 'order' in inspect.getargspec(np.copy)[0]:

# %%
# Open and read transcripts in NLTK
f1A=codecs.open('../../../private/brainstorming_viz_data/free_group/teamA_part1_divergent.txt', 'r', encoding='utf-8')
f1B=codecs.open('../../../private/brainstorming_viz_data/free_group/teamB_part1_divergent.txt', 'r', encoding='utf-8')
f1C=codecs.open('../../../private/brainstorming_viz_data/free_group/teamC_part1_divergent.txt', 'r', encoding='utf-8')
f1D=codecs.open('../../../private/brainstorming_viz_data/free_group/teamD_part1_divergent.txt', 'r', encoding='utf-8')
f1E=codecs.open('../../../private/brainstorming_viz_data/free_group/teamE_part1_divergent.txt', 'r', encoding='utf-8')
f1F=codecs.open('../../../private/brainstorming_viz_data/free_group/teamF_part1_divergent.txt', 'r', encoding='utf-8')
f1G=codecs.open('../../../private/brainstorming_viz_data/free_group/teamG_part1_divergent.txt', 'r', encoding='utf-8')
f1H=codecs.open('../../../private/brainstorming_viz_data/free_group/teamH_part1_divergent.txt', 'r', encoding='utf-8')
f1I=codecs.open('../../../private/brainstorming_viz_data/free_group/teamI_part1_divergent.txt', 'r', encoding='utf-8')

f2J1=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamJ_part1_divergent.txt', 'r', encoding='utf-8')
f2J2=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamJ_part3_divergent.txt', 'r', encoding='utf-8')
f2K1=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamK_part1_divergent.txt', 'r', encoding='utf-8')
f2K2=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamK_part3_divergent.txt', 'r', encoding='utf-8')
f2L1=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamL_part1_divergent.txt', 'r', encoding='utf-8')
f2L2=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamL_part3_divergent.txt', 'r', encoding='utf-8')
f2M1=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamM_part1_divergent.txt', 'r', encoding='utf-8')
f2M2=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamM_part2_3_convergent_divergent.txt', 'r', encoding='utf-8')
f2N1=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamN_part1_divergent.txt', 'r', encoding='utf-8')
f2N2=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamN_part3_divergent.txt', 'r', encoding='utf-8')
f2O1=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamO_part1_divergent.txt', 'r', encoding='utf-8')
f2O2=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamO_part2_3_conv_div.txt', 'r', encoding='utf-8')
f2P1=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamP_part1_divergent.txt', 'r', encoding='utf-8')
f2P2=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamP_part3_divergent.txt', 'r', encoding='utf-8')
f2Q1=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamQ_part1_divergent.txt', 'r', encoding='utf-8')
f2Q2=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamQ_part3_4_div_conv.txt', 'r', encoding='utf-8')
f2R1=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamR_part1_divergent.txt', 'r', encoding='utf-8')
f2R2=codecs.open('../../../private/brainstorming_viz_data/d-c_group/teamR_part3_divergent.txt', 'r', encoding='utf-8')

f1Temp = codecs.open('tempASCII', 'w', encoding='ascii', errors='ignore')
f2Temp = codecs.open('tempASCII', 'w', encoding='ascii', errors='ignore')
f1Temp.write('free_group/teamA_part1_divergent_bak.txt')
f2Temp.write('free_group/teamA_part1_convergent_bak.txt')
group1_divergent_raw = f1A.read() + f1B.read() + f1C.read() + f1D.read() + f1E.read() + \
                       f1F.read() + f1G.read() + f1H.read() + f1I.read()
group2_divergent_raw = f2J1.read() + f2J2.read() + f2K1.read() + f2K2.read() + f2L1.read() + f2L2.read() + \
                       f2M1.read() + f2M2.read() + f2N1.read() + f2N2.read() + f2O1.read() + f2O2.read() + \
                       f2P1.read() + f2P2.read() + f2Q1.read() + f2Q2.read() + f2R1.read() + f2R2.read() 
regex = re.compile(".*?\\[(.*?)\\]")

def removeObservations(test_str):
    # removes all text within parantheses
    # these are usually observations by the transcriber
    # and thus should not be considered in content analysis
    # code from http://stackoverflow.com/questions/14596884/remove-text-between-and-in-python
    ret = ''
    skip1c = 0
    skip2c = 0
    for i in test_str:
        if i == '[':
            skip1c += 1
        elif i == '(':
            skip2c += 1
        elif i == ']' and skip1c > 0:
            skip1c -= 1
        elif i == ')'and skip2c > 0:
            skip2c -= 1
        elif skip1c == 0 and skip2c == 0:
            ret += i
    return ret

group1_divergent = removeObservations(group1_divergent_raw)
group2_divergent = removeObservations(group2_divergent_raw)

# %%
# Extract Noun phrases using TextBlob
blobFreeGroup = TextBlob(group1_divergent)
blobDCGroup = TextBlob(group2_divergent)
nounFreeGroup = dict(blobFreeGroup.np_counts)
nounDCGroup = dict(blobDCGroup.np_counts)

# convert the above dicts to tupes, order them in descending order of frequency
import operator
nounFreeGrp_tuple = sorted(nounFreeGroup.items(), key=operator.itemgetter(1), reverse=True)
nounDCGrp_tuple = sorted(nounDCGroup.items(), key=operator.itemgetter(1), reverse=True)

#Then convert them back to dicts
from collections import OrderedDict
nounFreeGroupSorted = OrderedDict(nounFreeGrp_tuple)
nounDCGroupSorted = OrderedDict(nounDCGrp_tuple)

dfnp1 = pd.DataFrame(columns=['Noun phrases in Divergent phase Free Group', 'Frequencies'])
dfnp2 = pd.DataFrame(columns=['Noun phrases in Divergent phase D-C Group', 'Frequencies'])
u=1
for i in nounFreeGroupSorted:
    dfnp1.loc[u] = [i, nounFreeGroupSorted[i]]
    u+=1

u=1
for i in nounDCGroupSorted:
    dfnp2.loc[u] = [i, nounDCGroupSorted[i]]
    u+=1
    
print("The total number of noun phrases in the Free Group's divergent phase:", len(nounFreeGroupSorted))
dfnp1.head(25)
# Out:
# The total number of noun phrases in the Free Group's divergent phase: 2297
#    Noun phrases in Divergent phase Free Group  Frequencies
# 1                                        yeah          690
# 2                                          oh          203
# 3                                        it’s          148
# 4                                        okay          134
# 5                                         i’m          117
# 6                                      that’s          113
# 7                                        well           93
# 8                                      gon na           76
# 9                                       let’s           39
# 10                                     mm-hmm           38
# 11                                      right           34
# 12                                     that’d           32
# 13                                        cuz           31
# 14                                     wan na           29
# 15                                      we’re           27
# 16                                    there’s           26
# 17                                  good idea           23
# 18                                        huh           23
# 19                                     you’re           21
# 20                                       have           21
# 21                                       nerf           20
# 22                                     what’s           19
# 23                                    they’re           18
# 24                                    exactly           16
# 25                                       i’ll           16

# %%
print("The total number of noun phrases in the convergent phase:", len(nounDCGroupSorted))
dfnp2.head(25)
# Out:
# The total number of noun phrases in the convergent phase: 1903
#    Noun phrases in Divergent phase D-C Group  Frequencies
# 1                                       yeah          531
# 2                                       okay          186
# 3                                         oh          150
# 4                                       it’s          118
# 5                                     that’s           95
# 6                                        i’m           72
# 7                                    alright           38
# 8                                     gon na           37
# 9                                       well           35
# 10                                    that’d           32
# 11                                   frisbee           30
# 12                                    mm-hmm           28
# 13                                   there’s           21
# 14                                    wan na           21
# 15                                      dots           18
# 16                                     we’re           18
# 17                                     right           18
# 18                                    what’s           16
# 19                                      nice           16
# 20                                     let’s           15
# 21                            remote control           15
# 22                                     it’ll           14
# 23                                   's kind           14
# 24                                    you’re           12
# 25                                      he’s           12

# %%
# Common noun phrases in both phases
common = {}
notcommon = {}
dfc = pd.DataFrame(columns=["Common noun phrases", "Free Group", "D-C Group"])
u=1
for i in nounFreeGroupSorted:
    if i in nounDCGroupSorted:
        common[i] = min(nounFreeGroupSorted[i], nounDCGroupSorted[i])
        notcommon[i] = (nounFreeGroupSorted[i], nounDCGroupSorted[i])
        dfc.loc[u] = [i, nounFreeGroupSorted[i], nounDCGroupSorted[i]]
        u+=1
        
dfc
# Out:
#     Common noun phrases  Free Group  D-C Group
# 1                  yeah         690        531
# 2                    oh         203        150
# 3                  it’s         148        118
# 4                  okay         134        186
# 5                   i’m         117         72
# 6                that’s         113         95
# 7                  well          93         35
# 8                gon na          76         37
# 9                 let’s          39         15
# 10               mm-hmm          38         28
# 11                right          34         18
# 12               that’d          32         32
# 13                  cuz          31         12
# 14               wan na          29         21
# 15                we’re          27         18
# 16              there’s          26         21
# 17            good idea          23          8
# 18                  huh          23          7
# 19               you’re          21         12
# 20                 have          21         11
# 21                 nerf          20         11
# 22               what’s          19         16
# 23              they’re          18         10
# 24              exactly          16          5
# 25                 i’ll          16          7
# 26                  hmm          16          4
# 27        final concept          14          2
# 28                  pez          14          9
# 29               really          13          8
# 30                  co2          13          3
# ..                  ...         ...        ...
# 254          're gettin           1          1
# 255              unless           1          5
# 256        gon na shoot           1          1
# 257           exploding           1          2
# 258          absolutely           1          1
# 259          battleship           1          1
# 260         sure that’s           1          1
# 261             magnets           1          3
# 262             own way           1          2
# 263             someone           1          1
# 264            kids cuz           1          1
# 265        air pressure           1          1
# 266             they’ve           1          1
# 267        bouncy balls           1          1
# 268      paper airplane           1          1
# 269             fun toy           1          2
# 270         windup toys           1          1
# 271           'm gon na           1          7
# 272         plays music           1          1
# 273            sort of—           1          1
# 274            bastards           1          1
# 275        final design           1          1
# 276     target customer           1          1
# 277     different parts           1          1
# 278      different toys           1          1
# 279                  ow           1          1
# 280      different ones           1          2
# 281       that’s gon na           1          1
# 282                 mac           1          2
# 283               t-rex           1          1
#
# [283 rows x 3 columns]

# %%
print(common)
# Out:
# {'you’ve': 3, 'idea generation': 1, "'m gon na": 1, 'purdue': 3, 'everyone': 1, 'your': 4, 'high school': 2, 'senior design': 1, 'adult toy': 1, 'trivial': 1, 'here’s': 2, 'where’d': 1, 'army guys': 1, 'mechanical motion': 1, 'sure': 5, 'rock': 3, 'tootsie roll': 2, 'air pressure': 1, 'dots': 1, 'just starts': 1, 'somehow': 2, 'different parts': 1, "n't matter": 1, 'gon na work': 1, 'nontrivial motion': 6, 'final design': 1, 'nope': 2, 'non-trivial motion': 2, 'africa': 1, 'exploding': 1, "'re gon na": 3, 'kinda': 1, 'i’d': 8, 'draw': 3, 'anything': 7, 'that’s fine': 1, "ca n't": 7, 'drinking': 1, "n't need": 1, 'anyway': 1, 'yep': 3, 'fun game': 1, 'toy soldiers': 1, 'profile sketches': 1, 'rube goldberg': 2, 'wan na draw': 1, "'s fine": 1, 'dude': 2, 'different things': 4, 'cool idea': 1, 'bb': 1, 'type thing': 1, 'paper airplane': 1, 'remote control': 7, 'push': 1, 'different toys': 1, 'youtube': 1, 'we’d': 2, 'final concept': 2, "n't work": 1, 'wars': 2, 'hot wheels': 1, 'different ones': 1, 'action figure': 1, 'sorry': 8, 'new toys': 1, 'gon na end': 1, 'depends': 1, 'lego mindstorm': 1, 'barbie': 2, 'different gear ratios': 1, 'unless': 1, 'don’t wan na': 2, 'gon na shoot': 1, 'kids cuz': 1, 'somebody': 1, 'pez': 9, 'wheels': 1, 'don’t': 5, 'smarties': 3, 'co2': 3, 'different': 2, 'back flip': 1, 'hard part': 2, 'they’ve': 1, 'it’s gon na': 2, 'paddle boat': 1, 'small': 1, 'plastic': 1, 'you’ll': 2, 'bath toy': 1, 'own way': 1, 'bouncy balls': 1, 'bottle': 1, 'java': 1, 'destroy': 1, 'it’s awesome': 1, 'ours': 1, 'they’ll': 1, 'pretty legit': 1, 'have—i don’t': 1, 'someone': 1, 'tootsie rolls': 3, 'really': 8, 'you’d': 3, 'say': 5, 'frisbee': 7, 'think': 3, 'china': 1, 'fun toy': 1, 'isn’t': 1, 'start': 3, 'motion sensor': 1, 'going': 2, 'whoa': 1, 'board game': 4, "'s gon na": 3, 'we’re gon na': 2, 'army men': 1, 'certain amount': 1, 'spin': 1, 'dang': 1, 'shit ton': 1, 'spider': 1, 'does': 8, 'desk toy': 1, 'bop': 3, 'type': 1, 'spring mechanism': 1, 'try': 3, 'looks': 1, 'cool': 2, 'hovercraft': 2, 'two-point perspective': 2, 'planes': 1, 'basically': 6, 'player game': 1, 'kids': 4, 'toy ideas': 1, 'dinosaurs': 1, 'hold': 1, 'trains': 1, 'non-trivial': 2, 'wouldn’t': 1, 'wow': 3, 'candy': 1, 'got': 4, 'exact thing': 1, 'bastards': 1, 'olympics': 1, 'wait': 9, 'trampoline': 1, 'creative ideas': 5, 'certain point': 1, 'gon na —': 1, 'sounds': 2, 'great idea': 1, 'remember': 3, 'mechanism': 1, 'rc': 3, 'pull': 1, 'trivial motion': 1, 'darts': 1, 'shooter thing': 1, 'sock': 4, 'bad idea': 2, 'plays music': 1, 'doesn’t': 3, 'either': 1, 'it’ll': 5, 'transformer': 2, 'suction cups': 1, 'just pull': 1, 'set': 1, 'making': 2, 'legos': 6, 'absolutely': 1, 'water tank': 1, 'gon na draw': 1, "'re gettin": 1, 'fish': 1, 'elephant': 1, 'god': 3, 'mac': 1, 'can’t draw': 1, 'nozzle': 1, 'obviously': 2, 'whole thing': 3, 'person draw': 1, 'action figures': 1, 'coke': 1, 'i’ve': 10, 'actual ideas': 1, 'right time': 1, 'boom': 1, 'sort of—': 1, 'arduino': 2, 'hey': 6, 'off': 1, 'uh': 2, 'we’ve': 3, 'magnets': 1, 'that’s gon na': 1, 'keep': 2, 'target customer': 1, 'video games': 2, 'shoot': 1, 'he’s': 12, 'sure that’s': 1, 'windup toys': 1, 'entire thing': 1, 'doesn’t matter': 1, 'robots': 3, 'who': 5, 'educational game': 1, 'rancher': 2, 'power': 1, 'it’s kind': 1, 'kind': 7, 'pick': 1, 'ball and—': 1, 'segway': 1, 'sort': 1, 'possibly': 1, 'shoots air': 1, 'lego': 3, 'robotic arms': 1, 'scare': 1, 't-rex': 1, 'iu': 1, 'flying': 2, 'we’ll': 4, 'real thing': 1, 'cuz it’s': 3, 'battleship': 1, 'ow': 1, 'top view': 3, 'different motors': 1, 'nice': 4, 'shoots': 1, 'nontrivial': 3, 'definitely': 1, 'pretty sweet': 1, 'gotcha': 1, 'it’d': 8, 'water gun': 1, 'balls': 1, 'was': 1, 'gon na look': 1, 'hm': 1, 'ooh': 6, 'wan na pin': 1, 'a—some sort': 1, 'especially': 2, 'easy ones': 1, "'s like—": 1, 'be': 3}

# %%
# Noun phrases that can be removed:
to_be_removed = ['you’ve', "'m gon na", 'everyone', 'your', 'here’s', 
                 'where’d', 'sure', 'nope', 'kinda', 'i’d', 'anyway', 
                 'yep', 'dude', 'type thing', 'we’d', 'sorry', 'unless', 
                 'don’t wan na', 'somebody', 'don’t', 'they’ve', 
                 'it’s gon na', 'you’ll', 'it’s awesome', 'ours', 
                 'they’ll', 'pretty legit', 'have—i don’t', 'someone', 
                 'really', 'you’d', 'say', 'think', 'isn’t', 'going', 
                 'whoa', "'s gon na", 'we’re gon na', 'certain amount', 
                 'dang', 'shit ton', 'does', 'cool', 'basically', 
                 'wouldn’t', 'wow', 'got', 'exact thing', 'bastards', 
                 'wait', 'gon na —', 'sounds', 'great idea', 'doesn’t', 
                 'either', 'it’ll', 'absolutely', 'obviously', 
                 'whole thing', 'i’ve', 'actual ideas', 'sort of—', 
                 'hey', 'uh', 'we’ve', 'that’s gon na', 'he’s', 
                 'sure that’s', 'entire thing', 'it’s kind', 'kind', 
                 'sort', 'iu', 'we’ll', 'real thing', 'cuz it’s', 'ow', 
                 'nice', 'definitely', 'pretty sweet', 'gotcha', 'it’d', 
                 'was', 'gon na look', 'hm', 'ooh', 'wan na pin', 
                 'a—some sort', "'s like—", 'be'] 

keys_to_delete = []
for key in common.keys():
    if key in to_be_removed:
        keys_to_delete.append(key)
for key in keys_to_delete:
    del common[key] # could not have deleted item from iterable 
                    # from within the loop
ccommon=common.keys()

# %%
# Function to count co-occurrences of common noun phrases in sentences
def occurrences(source, terms):
    ALL_sentences=sent_tokenize(source) # creates a list of sentences
    combinations_terms = list(itertools.combinations(terms,2)) # NC2 of terms
    n = len(combinations_terms)
    occurlist = []
    for i in range(1, n):
        for j in ALL_sentences:
            temp = list(combinations_terms[i])
            # Find every combination of term 1 followed by term 2 in
            # term pair (1,2)
            out=re.compile(str(temp[0]) + '(.*?)' + str(temp[1]), 
                           re.DOTALL | re.IGNORECASE).findall(j)
            if out:
                occurlist.append(str(temp[0]) + ' - ' + str(temp[1]))
            # Find every combination of term 2 followed by term 1 in
            # term pair (1,2)
            out2 = re.compile(str(temp[1]) + '(.*?)' + str(temp[0]),
                             re.DOTALL | re.IGNORECASE).findall(j)
            if out2:
                occurlist.append(str(temp[1]) + ' - ' + str(temp[0]))
    occurdict = {}
    # count occurrences of term pairs
    for i in occurlist:
        if i not in occurdict:
            occurdict[i] = 1
        else : 
            occurdict[i] = occurdict[i] + 1
    return occurdict

# Call function to find divergent and convergent terms
FreeDivdict = occurrences(group1_divergent, ccommon)
DCDivdict = occurrences(group2_divergent, ccommon)
# nounDivdict = dict(nounDiv)
# nounConvdict = dict(nounConv)
# Divdict = occurrences(divergent, nounDiv)
# Convdict = occurrences(convergent, nounConv)

# %%
# Function to construct a graph of common noun phrases tied by 
# their co-occurrences in sentences of a transcript
def makegraph(occurrences):
    G = nx.Graph()
    weights = []
    for edgs,wt in occurrences.items():
        edg = edgs.split(' - ')
        G.add_edge(edg[0], edg[1], weight=wt)
        G.add_node(edg[0], label=edg[0])
        G.add_node(edg[1], label=edg[1])
        weights.append(wt)
    return [G, weights]

FreeGraphData = makegraph(FreeDivdict)
DCGraphData = makegraph(DCDivdict)
GFree = FreeGraphData[0]
GDC = DCGraphData[0]
FreeEdges = FreeGraphData[1]
DCEdges = DCGraphData[1]

# %%
print(GFree.edges(data=True))
# Out:
# [('player game', 'battleship', {'weight': 1}), ('player game', 'board game', {'weight': 1}), ('purdue', 'who', {'weight': 1}), ('purdue', 'spin', {'weight': 1}), ('just starts', 'off', {'weight': 2}), ('just starts', 'shoots', {'weight': 1}), ('just starts', 'shoot', {'weight': 1}), ('high school', 'making', {'weight': 1}), ('senior design', 'who', {'weight': 1}), ('hold', "n't matter", {'weight': 1}), ('hold', 'looks', {'weight': 1}), ('hold', 'spin', {'weight': 1}), ('hold', 'keep', {'weight': 1}), ('hold', 'pull', {'weight': 1}), ('hold', 'plastic', {'weight': 1}), ('trains', 'start', {'weight': 1}), ('trains', 'set', {'weight': 1}), ('trains', 'try', {'weight': 1}), ('trivial', 'trivial motion', {'weight': 2}), ('trivial', 'off', {'weight': 1}), ('trivial', 'anything', {'weight': 1}), ('trivial', 'nontrivial', {'weight': 2}), ('trivial', 'try', {'weight': 2}), ('trivial', 'frisbee', {'weight': 2}), ('trivial', 'nontrivial motion', {'weight': 2}), ('trivial', 'rc', {'weight': 1}), ('magnets', 'wheels', {'weight': 1}), ('magnets', 'rc', {'weight': 1}), ('magnets', 'try', {'weight': 1}), ('magnets', 'army men', {'weight': 2}), ('magnets', 'shoots', {'weight': 1}), ('magnets', 'shoot', {'weight': 1}), ('candy', 'start', {'weight': 1}), ('candy', 'god', {'weight': 1}), ('candy', 'draw', {'weight': 1}), ('candy', 'kids', {'weight': 1}), ('candy', 'balls', {'weight': 2}), ('candy', 'mac', {'weight': 2}), ('candy', 'who', {'weight': 1}), ('candy', 'rancher', {'weight': 1}), ('candy', 'can’t draw', {'weight': 1}), ('candy', 'shoot', {'weight': 2}), ('candy', 'keep', {'weight': 1}), ('candy', 'shoots', {'weight': 2}), ('candy', 'pez', {'weight': 1}), ('mechanical motion', 'start', {'weight': 1}), ('mechanical motion', 'fish', {'weight': 2}), ('mechanical motion', 'pull', {'weight': 1}), ('mechanical motion', 'just pull', {'weight': 1}), ('rock', 'somehow', {'weight': 1}), ('rock', 'bottle', {'weight': 3}), ('rock', 'shoot', {'weight': 1}), ('rock', 'sock', {'weight': 5}), ('rock', 'flying', {'weight': 1}), ('rock', 'different', {'weight': 1}), ('rock', 'robots', {'weight': 5}), ('rock', 'off', {'weight': 4}), ('rock', 'desk toy', {'weight': 1}), ('rock', 'type', {'weight': 1}), ('rock', 'different parts', {'weight': 1}), ('rock', 'shoots', {'weight': 1}), ('rock', 'power', {'weight': 1}), ('tootsie roll', 'making', {'weight': 1}), ('tootsie roll', 'pick', {'weight': 1}), ('back flip', 'rc', {'weight': 1}), ('plastic', 'push', {'weight': 1}), ('plastic', 'mac', {'weight': 1}), ('plastic', 'small', {'weight': 1}), ('plastic', 'shoot', {'weight': 1}), ('somehow', 'start', {'weight': 1}), ('somehow', 'shoot', {'weight': 1}), ('somehow', 'sock', {'weight': 1}), ('somehow', 'arduino', {'weight': 1}), ('somehow', 'spin', {'weight': 2}), ('somehow', 'certain point', {'weight': 1}), ('somehow', 'different', {'weight': 2}), ('somehow', 'robots', {'weight': 1}), ('somehow', 'push', {'weight': 1}), ('somehow', 'off', {'weight': 1}), ('somehow', 'power', {'weight': 2}), ('somehow', 'keep', {'weight': 1}), ('somehow', 'rc', {'weight': 1}), ('olympics', 'looks', {'weight': 1}), ('kids', 'start', {'weight': 1}), ('kids', 'video games', {'weight': 1}), ('kids', 'lego', {'weight': 1}), ('kids', 'scare', {'weight': 1}), ('kids', 'especially', {'weight': 2}), ('kids', 'legos', {'weight': 1}), ('kids', 'target customer', {'weight': 1}), ('kids', 'final concept', {'weight': 1}), ('kids', 'set', {'weight': 1}), ('kids', 'making', {'weight': 1}), ('kids', 'keep', {'weight': 1}), ('kids', 'china', {'weight': 1}), ('kids', 'try', {'weight': 1}), ('right time', 'push', {'weight': 1}), ('right time', 'off', {'weight': 1}), ('right time', 'spin', {'weight': 1}), ('flying', 'start', {'weight': 2}), ('flying', 'off', {'weight': 1}), ('flying', 'fish', {'weight': 6}), ("n't matter", 'draw', {'weight': 1}), ('certain point', 'spin', {'weight': 1}), ('certain point', 'different', {'weight': 1}), ('nontrivial motion', 'nontrivial', {'weight': 1}), ('nontrivial motion ...

# %%
print(GDC.edges(data=True))
# Out:
# [('purdue', 'who', {'weight': 1}), ('purdue', 'off', {'weight': 1}), ('purdue', 'spin', {'weight': 1}), ('purdue', 'rc', {'weight': 1}), ('kids', 'push', {'weight': 1}), ('kids', 'pez', {'weight': 1}), ('kids', 'drinking', {'weight': 1}), ('kids', 'off', {'weight': 1}), ('kids', 'different', {'weight': 1}), ('kids', 'pick', {'weight': 1}), ('kids', 'who', {'weight': 1}), ('kids', 'scare', {'weight': 1}), ('kids', 'transformer', {'weight': 1}), ('kids', 'planes', {'weight': 1}), ('kids', 'remember', {'weight': 1}), ('kids', 'power', {'weight': 1}), ('kids', 'try', {'weight': 1}), ('kids', 'robotic arms', {'weight': 1}), ('kids', 'set', {'weight': 1}), ('kids', 'pull', {'weight': 1}), ('kids', 'type', {'weight': 1}), ('different parts', 'type', {'weight': 1}), ('different parts', 'different', {'weight': 1}), ('hold', 'start', {'weight': 1}), ('hold', 'rock', {'weight': 1}), ('hold', 'rc', {'weight': 1}), ('hold', 'pull', {'weight': 1}), ('trains', 'who', {'weight': 1}), ('trains', 'off', {'weight': 1}), ('trains', 'wheels', {'weight': 1}), ('trains', 'planes', {'weight': 1}), ('non-trivial', 'trivial motion', {'weight': 1}), ('non-trivial', 'balls', {'weight': 1}), ('non-trivial', 'draw', {'weight': 1}), ('non-trivial', 'non-trivial motion', {'weight': 1}), ('non-trivial', 'trivial', {'weight': 1}), ('magnets', 'rock', {'weight': 1}), ('magnets', 'rc', {'weight': 1}), ('candy', 'god', {'weight': 1}), ('candy', 'start', {'weight': 1}), ('candy', 'shoot', {'weight': 2}), ('candy', 'action figure', {'weight': 1}), ('candy', 'creative ideas', {'weight': 1}), ('candy', 'shoots', {'weight': 2}), ('barbie', 'anything', {'weight': 1}), ('rock', 'somehow', {'weight': 1}), ('rock', 'anything', {'weight': 1}), ('rock', 'shoot', {'weight': 1}), ('rock', 'sock', {'weight': 11}), ('rock', 'flying', {'weight': 1}), ('rock', 'mac', {'weight': 1}), ('rock', 'type', {'weight': 1}), ('rock', 'try', {'weight': 1}), ('rock', 'set', {'weight': 1}), ('rock', 'robots', {'weight': 6}), ('rock', 'off', {'weight': 1}), ('rock', 'plastic', {'weight': 1}), ('pick', 'elephant', {'weight': 1}), ('pick', 'somehow', {'weight': 1}), ('pick', 'shoot', {'weight': 1}), ('pick', 'try', {'weight': 1}), ('pick', 'final concept', {'weight': 1}), ('pick', 'fish', {'weight': 2}), ('pick', 'making', {'weight': 1}), ('pick', 'planes', {'weight': 1}), ('pick', 'profile sketches', {'weight': 1}), ('air pressure', 'mechanism', {'weight': 1}), ('dots', 'start', {'weight': 2}), ('dots', 'draw', {'weight': 1}), ('just starts', 'rc', {'weight': 1}), ('somehow', 'push', {'weight': 1}), ('somehow', 'wheels', {'weight': 1}), ('somehow', 'type', {'weight': 1}), ('somehow', 'flying', {'weight': 1}), ('somehow', 'shoot', {'weight': 1}), ('somehow', 'making', {'weight': 1}), ('olympics', 'action figure', {'weight': 1}), ('different ones', 'different', {'weight': 1}), ('educational game', 'making', {'weight': 1}), ("n't matter", 'making', {'weight': 1}), ('trampoline', 'set', {'weight': 1}), ('nontrivial motion', 'hovercraft', {'weight': 1}), ('nontrivial motion', 'shoot', {'weight': 1}), ('nontrivial motion', 'rc', {'weight': 1}), ('elephant', 'pez', {'weight': 1}), ('wheels', 'who', {'weight': 1}), ('wheels', 'start', {'weight': 1}), ('wheels', 'small', {'weight': 1}), ('wheels', 'spin', {'weight': 1}), ('wheels', 'off', {'weight': 2}), ('wheels', 'different', {'weight': 1}), ('wheels', 'rc', {'weight': 1}), ('non-trivial motion', 'trivial motion', {'weight': 1}), ('non-trivial motion', 'balls', {'weight': 1}), ('non-trivial motion', 'draw', {'weight': 1}), ('non-trivial motion', 'trivial', {'weight': 1}), ('water tank', 'bb', {'weight': 1}), ('pull', 'push', {'weight': 1}), ('pull', 'remember', {'weight': 1}), ('pull', 'power', {'weight': 1}), ('pull', 'try', {'weight': 1}), ('pull', 'shoot', {'weight': 1}), ('person draw', 'start', {'weight': 1}), ('person draw', 'draw', {'weight': 1}), ('start', 'draw', {'weight': 3}), ('start', 'power', {'weight': 1}), ('start', 'lego', {'weight':  ...

# %%
# Plot graph of common phrases in Team A's divergent phase
from tools import draw_network
pos = nx.spring_layout(GFree, iterations=20)
sstt="Team A's wordnet during divergent phase of brainstorming"
possit=draw_network(GFree,sstt,pos=pos,with_edgewidth=True,withLabels=True,
                    labfs=15,valpha=0.2,ealpha=0.7,labelfont=15)
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
# Compute centralities of cmmon phrases in the graph of the divergent process

from tools import draw_centralities_subplots
centrali=draw_centralities_subplots(GDiv, pos, withLabels=True,labfs=5,
                                   figsi=(15, 15), ealpha=1, vals=True)
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
# Table of centralities of common phrases in the graph
dfcdiv = pd.DataFrame()
# The rest needs to be sorted out; version incompatibility

# %%
# detecting communities of common phrases
# %autoreload 2
from tools import draw_comms, modul_arity, print_communities
part, nodper = print_communities(GDiv, sstt)

d=0.8 
dd=0.8
c=1.2
cc=1.4
alpha=0.2
ealpha=.7
vcc={}

sstta="Team A's divergent wordnet with "+ str(max(part.values())+1) + " Themes" 
draw_comms(GDiv,GDiv.nodes(),[],[],[] ,part,part,d,dd,c,cc,alpha,ealpha,nodper,sstta,titlefont=20,labelfont=15,valpha=0.5)
# Out:
# Number of communities of  Team A's wordnet during divergent phase of brainstorming  =  3
# Community partition of  Team A's wordnet during divergent phase of brainstorming :
# [['mechanical motion', 'rc', 'say', 'have'], ['that’s', 'it’s', 'cool', 'good idea'], ['here’s', 'right', 'shoots']]
# Community modularity of Team A's wordnet during divergent phase of brainstorming  =  0.275390625
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
# Plot graph of common phrases in Team A's convergent phase
from tools import draw_network
pos = nx.spring_layout(GConv, iterations=20)
sstt="Team A's wordnet during convergent phase of brainstorming"
possit=draw_network(GConv,sstt,pos=pos,with_edgewidth=True,withLabels=True,
                    labfs=15,valpha=0.2,ealpha=0.7,labelfont=15)
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
# Compute centralities of cmmon phrases in the graph of the divergent process

from tools import draw_centralities_subplots
centrali=draw_centralities_subplots(GConv, pos, withLabels=True,labfs=5,
                                   figsi=(15, 15), ealpha=1, vals=True)
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
# detecting communities of common phrases
# %autoreload 2
from tools import draw_comms, modul_arity, print_communities
part, nodper = print_communities(GConv, sstt)

d=0.8 
dd=0.8
c=1.2
cc=1.4
alpha=0.2
ealpha=.7
vcc={}

sstta="Team A's divergent wordnet with "+ str(max(part.values())+1) + " Themes" 
draw_comms(GConv,GConv.nodes(),[],[],[] ,part,part,d,dd,c,cc,alpha,ealpha,nodper,sstta,titlefont=20,labelfont=15,valpha=0.5)
# Out:
# Number of communities of  Team A's wordnet during convergent phase of brainstorming  =  3
# Community partition of  Team A's wordnet during convergent phase of brainstorming :
# [['i’m', 'here’s', 'whole thing', 'have'], ['rc', 'it’s'], ['that’s', 'say', 'right']]
# Community modularity of Team A's wordnet during convergent phase of brainstorming  =  0.293388429752066
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
# Plotting the Hillary Clinton vs. Bernie Sanders wordnet

G = nx.Graph()
G.add_edges_from(GDiv.edges())
G.add_edges_from(GConv.edges())
pos=nx.spring_layout(G)
# pos=nx.spring_layout(G)
sstt="Team A Divergent vs. Convergent wordnet \n Divergent edges are cyan, Convergent edges are green and common edges are red"
plt.figure(figsize=(15,15))
common_edges=set(GDiv.edges()).intersection(set(GConv.edges()))
HCandBSedges = list(common_edges)
Cedges=set(GDiv.edges()).difference(set(GConv.edges()))
HCedges = list(Cedges)
Sedges=set(GConv.edges()).difference(set(GDiv.edges()))
BSedges = list(Sedges)
nx.draw_networkx_nodes(G,pos,withLabels=True,node_color='b',node_size=1000,alpha=0.15)
nx.draw_networkx_edges(G,pos,edgelist=HCandBSedges,width=5,alpha=0.5,edge_color='r')
nx.draw_networkx_edges(G,pos,edgelist=HCedges,width=5,alpha=0.5,edge_color='c')
nx.draw_networkx_edges(G,pos,edgelist=BSedges,width=5,alpha=0.5,edge_color='g')
nx.draw_networkx_labels(G,pos=pos,font_size=15)
plt.title(sstt,fontsize=20)
kk=plt.axis('off')
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
